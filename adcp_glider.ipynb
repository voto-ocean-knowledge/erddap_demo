# %% [markdown]
# # ADCP glider

# %%
import utils

# %% [markdown]
# **NB!** Must delete the delayed mode dataset if you had already downloaded it before first running this script. Check the directory voto_erdda_data_cache.

# %%
# !rm voto_erddap_data_cache/delayed_SEA067_M32.nc

# %%
datasets_to_download = ['delayed_SEA067_M32', "nrt_SEA067_M32"]
ds_dict = utils.download_glider_dataset(datasets_to_download, nrt_only=False, adcp=True)
ds = ds_dict['delayed_SEA067_M32']
nrt = ds_dict['nrt_SEA067_M32']
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Found voto_erddap_data_cache/adcp_SEA067_M32.nc. Loading from disk
# Writing voto_erddap_data_cache/delayed_SEA067_M32.nc
# ...
# Found voto_erddap_data_cache/adcp_SEA067_M32.nc. Loading from disk
# WARNING: matching adcp data to nearest nrt timestamp. Potential missmatch of ~ 15 seconds. Use delayed mode data for closer timestamp match

# %%
nrt.depth.plot()

# %%
nrt.adcp_correlation[:,:,2].plot()
